# %%
# !unzip car
# Out:
# Archive:  car.zip
#   inflating: car/README.roboflow.txt
#   inflating: car/test/labels/Cars86_png.rf.5a2b4c098a59d3db3ab0989957a931b3.txt
#   inflating: car/test/images/no_damage_61_jpg.rf.da3fb178d525d122b51abdbc9d072f99.jpg
#   inflating: car/test/images/Cars414_png.rf.270dbf8618e857ff57d37e32b14813e2.jpg
#   inflating: car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg
#   inflating: car/test/images/Cars54_png.rf.343c552d210654b382802f7e663236e5.jpg
#   inflating: car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg
#   inflating: car/data.yaml
#   inflating: car/test/images/Cars306_png.rf.dd001ad2f0e6c305bf5bd3d704eebd75.jpg
#   inflating: car/test/images/Cars411_png.rf.7b08e44315268c4a52fec6cb2901269b.jpg
#   inflating: car/test/images/no_damage_57_jpg.rf.ec7d0a849593e84ceac8584cad90441a.jpg
#   inflating: car/test/images/Cars53_png.rf.0edd90a3213d88f02aba9ba00ce5e472.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 9.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
model = YOLO('yolov8n.yaml')

# %%
model.train(data='/content/car/data.yaml', epochs=50)
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.val(data='/content/car/data.yaml')
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,008,768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100%|██████████| 160/160 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
#                    all        160       1055      0.639      0.605      0.611      0.384
#                   boot         35         39      0.688      0.509      0.624      0.338
#                    car        142        145      0.907      0.966      0.948      0.795
# ...

# %%
Image(filename='/content/runs/detect/train42/confusion_matrix.png',height=500)

# %%
Image(filename='/content/runs/detect/train4/results.png', height=500)
